# %%
import pandas as pd

# %% [markdown]
# # First Python Notebook
#
# Hello world!

# %% [markdown]
# # Millennials Project
#
# First we begin by loading in our data.

# %%
millennials = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Millenials Moving/Data/MILLENIALSFINALLIST.csv")

# %% [markdown]
# <p>Now we will start the analysis. Which is really, really good. </p>

# %% [markdown]
# Now we will start the analysis. Which is really, really good.

# %%
# %matplotlib inline

# %%
millennials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 18 columns):
# County                            147 non-null object
# City_Metro                        147 non-null object
# List_Frequency_Dummy              147 non-null int64
# Walk_Score                        147 non-null float64
# Rent                              147 non-null int64
# Regional_Price_Parity             147 non-null float64
# Population_2015                   147 non-null int64
# Mil_Population_2015               147 non-null int64
# CurrentMilPercentage              147 non-null float64
# TotalMilChange                    147 non-null float64
# AvgMilChange                      147 non-null float64
# Unemployment_Rate_2016            147 non-null float64
# Median_Income                     147 non-null int64
# Median_Income_Percentage_State    147 non-null float64
# TotalURChange                     147 non-null float64
# ...

# %%
millennials.sort_values("Regional_Price_Parity" , ascending=True)
# Out:
#                                          County        City_Metro  \
# 64                   Craighead County, Arkansas         Jonesboro
# 115                       Cole County, Missouri    Jefferson City
# 94                  Bartholomew County, Indiana          Columbus
# 107                 Montgomery County, Virginia    Christiansburg
# 13             Monongalia County, West Virginia        Morgantown
# 129                     Greene County, Missouri       Springfield
# 47                        Kent County, Michigan      Grand Rapids
# 90                     Bonneville County, Idaho       Idaho Falls
# 118                    Twin Falls County, Idaho       Idaho Falls
# 100                   Buchanan County, Missouri        St. Joseph
# 135                    Muscogee County, Georgia          Columbus
# 41                        Bannock County, Idaho         Pocatello
# 114                       Hamilton County, Ohio        Cincinnati
# ...

# %%
prop = millennials.sort_values("Regional_Price_Parity" , ascending=True).head(10)

# %%
prop.head()
# Out:
#                                County      City_Metro  List_Frequency_Dummy  \
# 64         Craighead County, Arkansas       Jonesboro                     0
# 115             Cole County, Missouri  Jefferson City                     0
# 94        Bartholomew County, Indiana        Columbus                     0
# 107       Montgomery County, Virginia  Christiansburg                     0
# 13   Monongalia County, West Virginia      Morgantown                     0
#
#      Walk_Score  Rent  Regional_Price_Parity  Population_2015  \
# 64         23.0   640                   82.0           101409
# 115        25.0   521                   82.2            76533
# 94         25.0   783                   87.7            79488
# 107        26.0   812                   88.2            96467
# 13         54.0   658                   88.5           101668
#
#      Mil_Population_2015  CurrentMilPercentage  TotalMilChange  AvgMilChange  \
# ...

# %%
prop.Regional_Price_Parity.plot.bar()

# %%
prop.Rent.plot.barh()

# %% [markdown]
# chart = prop.head().Rent.plot.barh
# chart.set_yticklabels(prop.City_Metro)

# %%
chart = prop.head().Rent.plot.barh()
chart.set_yticklabels(prop.City_Metro)

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-d3d27f1d6222> in <module>()
# ----> 1 merged = pd.merge(prop, contribs, on="calaccess_committee_id")
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/reshape/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
support.amount.sum() / merged.amount.sum()

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()

# %%
def combine_names(row):
    if row.contributor_fullname.startswith('SEAN PARKER'):
        return 'SEAN PARKER'
    return row.contributor_fullname

# %%
def combine_names(row):
    if row.contributor_fullname.startswith('SEAN PARKER'):
        return 'SEAN PARKER'
    return row.contributor_fullname

# %%
dd = pd.read_json("http://api.census.gov/data/2015/acs5/profile?get=NAME,DP03_0025E&for=county:*&key=")

# %%
dd.head()
# Out:
#                          0           1      2       3
# 0                     NAME  DP03_0025E  state  county
# 1  Autauga County, Alabama        26.5     01     001
# 2  Baldwin County, Alabama        26.4     01     003
# 3  Barbour County, Alabama        24.1     01     005
# 4     Bibb County, Alabama        28.8     01     007

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3221 entries, 0 to 3220
# Data columns (total 4 columns):
# 0    3221 non-null object
# 1    3221 non-null object
# 2    3221 non-null object
# 3    3221 non-null object
# dtypes: object(4)
# memory usage: 125.8+ KB

# %%
dd2 = df1.ix[2:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-d37d2819f64c> in <module>()
# ----> 1 dd2 = df1.ix[2:]
#
# NameError: name 'df1' is not defined

# %%
dd2 = dd.ix[2:]
# Out:
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
dd2.head()
# Out:
#                          0     1   2    3
# 2  Baldwin County, Alabama  26.4  01  003
# 3  Barbour County, Alabama  24.1  01  005
# 4     Bibb County, Alabama  28.8  01  007
# 5   Blount County, Alabama  34.9  01  009
# 6  Bullock County, Alabama  27.5  01  011

# %%
travel_times = dd.ix[1:]

# %%
travel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-8ac993c5c888> in <module>()
# ----> 1 travel
#
# NameError: name 'travel' is not defined

# %%
travel_times.head()
# Out:
#                          0     1   2    3
# 1  Autauga County, Alabama  26.5  01  001
# 2  Baldwin County, Alabama  26.4  01  003
# 3  Barbour County, Alabama  24.1  01  005
# 4     Bibb County, Alabama  28.8  01  007
# 5   Blount County, Alabama  34.9  01  009

# %%
travel_times.value_sort('1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-6d03a261ab99> in <module>()
# ----> 1 travel_times.value_sort('1')
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_sort'

# %%
travel_times.sort_values('1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-bb40524284f6> in <module>()
# ----> 1 travel_times.sort_values('1')
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3184
#    3185             by = by[0]
# -> 3186             k = self.xs(by, axis=other_axis).values
#    3187             if k.ndim == 2:
#    3188
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    2021
#    2022         if axis == 1:
# -> 2023             return self[key]
#    2024
#    2025         self._consolidate_inplace()
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
# ...

# %%
travel_times.mean('1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-4856fb3fe183> in <module>()
# ----> 1 travel_times.mean('1')
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6340                                       skipna=skipna)
#    6341         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6342                             numeric_only=numeric_only)
#    6343
#    6344     return set_function_name(stat_func, name, cls)
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/frame.pyc in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    5045     def _reduce(self, op, name, axis=0, skipna=True, numeric_only=None,
#    5046                 filter_type=None, **kwds):
# ...

# %%
travel_times.mean(1)
# Out:
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
#         ..
# 3191   NaN
# 3192   NaN
# 3193   NaN
# 3194   NaN
# 3195   NaN
# 3196   NaN
# 3197   NaN
# 3198   NaN
# 3199   NaN
# 3200   NaN
# 3201   NaN
# 3202   NaN
# 3203   NaN
# 3204   NaN
# 3205   NaN
# 3206   NaN
# 3207   NaN
# 3208   NaN
# 3209   NaN
# 3210   NaN
# 3211   NaN
# 3212   NaN
# 3213   NaN
# 3214   NaN
# 3215   NaN
# 3216   NaN
# 3217   NaN
# 3218   NaN
# 3219   NaN
# 3220   NaN
# Length: 3220, dtype: float64

# %%
travel_times.sort_values(1)
# Out:
#                                        0     1   2    3
# 985                Thomas County, Kansas  10.1  20  193
# 72           Bristol Bay Borough, Alaska  10.4  02  060
# 2394         Hughes County, South Dakota  10.6  46  065
# 956                  Ness County, Kansas  10.8  20  135
# 2373    Charles Mix County, South Dakota  10.8  46  023
# 2578             Culberson County, Texas  11.0  48  109
# 1624             Liberty County, Montana  11.0  30  051
# 81         Kodiak Island Borough, Alaska  11.3  02  150
# 1690           Garfield County, Nebraska  11.3  31  071
# 1727         Red Willow County, Nebraska  11.3  31  145
# 982               Stanton County, Kansas  11.3  20  187
# 1608             Daniels County, Montana  11.3  30  019
# 1227     Nantucket County, Massachusetts  11.4  25  019
# 1661          Box Butte County, Nebraska  11.5  31  013
# 2658                  King County, Texas  11.6  48  269
# 1663              Brown County, Nebraska  11.6  31  017
# ...

# %%
import pandas as pd

# %%
commute = pd.read_json("/Users/alexmahadevan/Downloads/profile.json")

# %%
commute.head()
# Out:
#                          0           1      2       3
# 0                     NAME  DP03_0025E  state  county
# 1  Autauga County, Alabama        26.5     01     001
# 2  Baldwin County, Alabama        26.4     01     003
# 3  Barbour County, Alabama        24.1     01     005
# 4     Bibb County, Alabama        28.8     01     007

# %%
commute.rename(columns = {'0':'NAME' , '1' : 'TIME'}, inplace = True)

# %%
commute.head()
# Out:
#                          0           1      2       3
# 0                     NAME  DP03_0025E  state  county
# 1  Autauga County, Alabama        26.5     01     001
# 2  Baldwin County, Alabama        26.4     01     003
# 3  Barbour County, Alabama        24.1     01     005
# 4     Bibb County, Alabama        28.8     01     007

# %%
import ijson

# %%
commute = "m/Users/alexmahadevan/Downloads/profile.json"

# %%
commute.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-52ad9cd52b55> in <module>()
# ----> 1 commute.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
print(columns[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-ddea28fe3111> in <module>()
#       1
# ----> 2 print(columns[0])
#
# NameError: name 'columns' is not defined

# %%
print

# %%
commute
# Out:
# 'm/Users/alexmahadevan/Downloads/profile.json'

# %%
with open(commute, 'r') as f:
    objects = ijson.items(f, 'meta.view.columns.item')
    columns = list(objects)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-75-6a3924f2068b> in <module>()
# ----> 1 with open(commute, 'r') as f:
#       2     objects = ijson.items(f, 'meta.view.columns.item')
#       3     columns = list(objects)
#
# IOError: [Errno 2] No such file or directory: 'm/Users/alexmahadevan/Downloads/profile.json'

# %%
commute2 = "/Users/alexmahadevan/Downloads/profile.json"

# %%
with open(commute2, 'r') as f:
    objects = ijson.items(f, 'meta.view.columns.item')
    columns = list(objects)

# %%
print(columns[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-b9e8a1322d8a> in <module>()
# ----> 1 print(columns[0])
#
# IndexError: list index out of range

# %%
top_supporters.groupby(
    "contributor_cleanname"
).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-54a217790b40> in <module>()
# ----> 1 top_supporters.groupby(
#       2     "contributor_cleanname"
#       3 ).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)
#
# NameError: name 'top_supporters' is not defined

# %%
top_supporters.apply(combine_names, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-447c64b4a49a> in <module>()
# ----> 1 top_supporters.apply(combine_names, axis=1)
#
# NameError: name 'top_supporters' is not defined

# %%
commute_time = pd.read_cvs("/Users/alexmahadevan/Desktop/commute times.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-34f494dc0adc> in <module>()
# ----> 1 commute_time = pd.read_cvs("/Users/alexmahadevan/Desktop/commute times.csv")
#
# AttributeError: 'module' object has no attribute 'read_cvs'

# %%
import pandas as pd

# %%
commute_time = pd.read_csv("/Users/alexmahadevan/Desktop/commute times.csv")

# %%
commute_time.head()
# Out:
#                     County  Commute_time  state  county
# 0  Autauga County, Alabama          26.5      1       1
# 1  Baldwin County, Alabama          26.4      1       3
# 2  Barbour County, Alabama          24.1      1       5
# 3     Bibb County, Alabama          28.8      1       7
# 4   Blount County, Alabama          34.9      1       9

# %%
commute_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 4 columns):
# County          3220 non-null object
# Commute_time    3220 non-null float64
# state           3220 non-null int64
# county          3220 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 100.7+ KB

# %%
commute_time = pd.DataFrame(commute_time.row.str.split(',',1).tolist(),
                                   columns = ['County','State'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-570971d65900> in <module>()
# ----> 1 commute_time = pd.DataFrame(commute_time.row.str.split(',',1).tolist(),
#       2                                    columns = ['County','State'])
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
commute_time = pd.DataFrame(commute_time.Commute_time.str.split(',',1).tolist(),
                                   columns = ['County','State'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-2fae796cd089> in <module>()
# ----> 1 commute_time = pd.DataFrame(commute_time.Commute_time.str.split(',',1).tolist(),
#       2                                    columns = ['County','State'])
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3075         if (name in self._internal_names_set or name in self._metadata or
#    3076                 name in self._accessors):
# -> 3077             return object.__getattribute__(self, name)
#    3078         else:
#    3079             if name in self._info_axis:
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/base.pyc in __get__(self, instance, owner)
#     241             # this ensures that Series.str.<method> is well defined
# ...

# %%
commute_time = pd.DataFrame(commute_time.County.str.split(',',1).tolist(),
                                   columns = ['County','State'])

# %%
commute_time.head()
# Out:
#            County     State
# 0  Autauga County   Alabama
# 1  Baldwin County   Alabama
# 2  Barbour County   Alabama
# 3     Bibb County   Alabama
# 4   Blount County   Alabama

# %%
commute_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 2 columns):
# County    3220 non-null object
# State     3220 non-null object
# dtypes: object(2)
# memory usage: 50.4+ KB

# %%
commute_time2 = pd.read_csv("/Users/alexmahadevan/Desktop/commute times.csv")

# %%
com = commute_time2['County'].str[1:-1].str.split(',', expand=True).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-2b527a968c3b> in <module>()
# ----> 1 com = commute_time2['County'].str[1:-1].str.split(',', expand=True).astype(float)
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
com = commute_time2['County'].str[1:-1].str.split(',', expand=True)

# %%
com.head()
# Out:
#                0        1
# 0  utauga County   Alabam
# 1  aldwin County   Alabam
# 2  arbour County   Alabam
# 3     ibb County   Alabam
# 4   lount County   Alabam

# %%
commute3 = pd.read_csv("/Users/alexmahadevan/Desktop/commute times.csv")

# %%
df2 = pd.DataFrame(commute3)
print df2
# Out:
#                                      County  Commute_time  state  county
# 0                   Autauga County, Alabama          26.5      1       1
# 1                   Baldwin County, Alabama          26.4      1       3
# 2                   Barbour County, Alabama          24.1      1       5
# 3                      Bibb County, Alabama          28.8      1       7
# 4                    Blount County, Alabama          34.9      1       9
# 5                   Bullock County, Alabama          27.5      1      11
# 6                    Butler County, Alabama          24.6      1      13
# 7                   Calhoun County, Alabama          24.1      1      15
# 8                  Chambers County, Alabama          25.1      1      17
# 9                  Cherokee County, Alabama          27.4      1      19
# 10                  Chilton County, Alabama          32.0      1      21
# 11                  Choctaw County, Alabama          30.7      1      23
# ...

# %%
df2[['County','State']] = pd.DataFrame([x for x in df2.County])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-b19120dfe548> in <module>()
# ----> 1 df2[['County','State']] = pd.DataFrame([x for x in df2.County])
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2324
#    2325         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2326             self._setitem_array(key, value)
#    2327         elif isinstance(key, DataFrame):
#    2328             self._setitem_frame(key, value)
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/frame.pyc in _setitem_array(self, key, value)
#    2348             if isinstance(value, DataFrame):
#    2349                 if len(value.columns) != len(key):
# -> 2350                     raise ValueError('Columns must be same length as key')
# ...

# %%
import pandas as pd

# %%
commute = pd.read_csv("/Users/alexmahadevan/Desktop/commute times.csv")

# %%
commute.head()
# Out:
#            County     State  Commute_time  Population
# 0  Autauga County   Alabama          26.5       55416
# 1  Baldwin County   Alabama          26.4      208563
# 2  Barbour County   Alabama          24.1       25965
# 3     Bibb County   Alabama          28.8       22643
# 4   Blount County   Alabama          34.9       57704

# %%
commute.Population.median()
# Out:
# 25771.0

# %%
commute.Population.mean()
# Out:
# 102841.34723106302

# %%
commute_large = commute[commute.Population > 102841.34723106302]

# %%
commute_large.head()
# Out:
#               County     State  Commute_time  Population
# 1     Baldwin County   Alabama          26.4      208563
# 7     Calhoun County   Alabama          24.1      114611
# 34    Houston County   Alabama          21.4      104056
# 36  Jefferson County   Alabama          23.6      659521
# 40        Lee County   Alabama          21.7      158991

# %%
commute_large.sort_values('Commute_time' , ascending =False)
# Out:
#                          County          State  Commute_time  Population
# 1830               Bronx County       New York          43.0     1455720
# 1200             Charles County       Maryland          42.8      157705
# 1870            Richmond County       New York          42.6      476015
# 1868              Queens County       New York          42.6     2333054
# 1851               Kings County       New York          41.7     2629150
# 2905            Stafford County       Virginia          40.5      144361
# 2892      Prince William County       Virginia          39.6      455210
# 2288              Monroe County   Pennsylvania          38.7      166098
# 2904        Spotsylvania County       Virginia          38.2      132010
# 1792              Sussex County     New Jersey          38.1      142522
# 496             Paulding County        Georgia          37.3      155825
# 1208     Prince George's County       Maryland          36.5      908049
# ...

# %%
commute.sort_values('Commute_time' , ascending =False)
# Out:
#                           County           State  Commute_time  Population
# 2295                 Pike County    Pennsylvania          44.0       55562
# 1830                Bronx County        New York          43.0     1455720
# 1200              Charles County        Maryland          42.8      157705
# 2909               Warren County        Virginia          42.7       39155
# 1870             Richmond County        New York          42.6      476015
# 1868               Queens County        New York          42.6     2333054
# 2911         Westmoreland County        Virginia          42.5       17592
# 291                  Park County        Colorado          42.4       17166
# 1851                Kings County        New York          41.7     2629150
# 2999                 Clay County   West Virginia          41.4        8859
# 601               Calhoun County        Illinois          41.1        4894
# ...

# %%
white_house = pd.read_csv("/Users/alexmahadevan/Downloads/2016-Report-White-House-Staff.csv")

# %%
white_house.head()
# Out:
#                              Name    Status  Salary  Pay Basis  \
# 0           Abizaid, Christine S.  Detailee  156552  Per Annum
# 1            Abraham, Yohannes A.  Employee  132000  Per Annum
# 2              Abramson, Jerry E.  Employee  157299  Per Annum
# 3  Adams-Falconer, Jr., Thomas M.  Employee   45613  Per Annum
# 4              Adler, Caroline E.  Employee  115664  Per Annum
#
#                                       Position Title  White House Review
# 0                      ADVISOR TO THE CHIEF OF STAFF                 NaN
# 1  DEPUTY ASSISTANT TO THE PRESIDENT FOR INTERGOV...                 NaN
# 2  DEPUTY ASSISTANT TO THE PRESIDENT AND DIRECTOR...                 NaN
# 3   PRESS ASSISTANT FOR REGIONAL AND SPECIALTY MEDIA                 NaN
# 4  SPECIAL ASSISTANT TO THE PRESIDENT AND DIRECTO...                 NaN

# %%
white_house.Salary.describe()
# Out:
# count       472.000000
# mean      84223.625000
# std       38853.242325
# min           0.000000
# 25%       50730.000000
# 50%       73051.000000
# 75%      112722.000000
# max      176461.000000
# Name: Salary, dtype: float64

# %%
white_house.sort_values('Salary' , ascending=False)
# Out:
#                        Name    Status  Salary  Pay Basis  \
# 471      Zients, Jeffrey D.  Employee  176461  Per Annum
# 304         Mu�oz, Cecilia   Employee  176461  Per Annum
# 68    Canegallo, Kristie A.  Employee  176461  Per Annum
# 93        Cushman, Chase M.  Employee  176461  Per Annum
# 125      Earnest, Joshua R.  Employee  176461  Per Annum
# 128    Eggleston, Warren N.  Employee  176461  Per Annum
# 198     Jarrett, Valerie B.  Employee  176461  Per Annum
# 200   Johnson, Broderick D.  Employee  176461  Per Annum
# 214         Keenan, Cody S.  Employee  176461  Per Annum
# 275     McDonough, Denis R.  Employee  176461  Per Annum
# 295         Monaco, Lisa O.  Employee  176461  Per Annum
# 52   Breckenridge, Anita J.  Employee  176461  Per Annum
# 355     Rhodes, Benjamin J.  Employee  176461  Per Annum
# 356          Rice, Susan E.  Employee  176461  Per Annum
# 419     Tchen, Christina M.  Employee  176461  Per Annum
# ...

# %%
white_house.sort_values('Salary' , ascending=True)
# Out:
#                        Name    Status  Salary  Pay Basis  \
# 315     Oakar, Catherine R.  Employee       0  Per Annum
# 99         Davies, Susan M.  Employee       0  Per Annum
# 321           Park, Todd Y.  Employee       0  Per Annum
# 167        Grega, Claire A.  Employee   42000  Per Annum
# 252      Lindgren, Carly E.  Employee   42000  Per Annum
# 166         Gray, Joshua D.  Employee   42000  Per Annum
# 76          Chase, Sarah W.  Employee   42000  Per Annum
# 159    Glazer, Alexandra S.  Employee   42000  Per Annum
# 32     Beckwith, Matthew M.  Employee   42000  Per Annum
# 142      Flaga, Nicholas R.  Employee   42000  Per Annum
# 137      Farishta, Karim N.  Employee   42000  Per Annum
# 331    Phillips, Gregory H.  Employee   42000  Per Annum
# 15        Appelbaum, Mia G.  Employee   42000  Per Annum
# 266   Mason, III, Lawrence   Employee   42000  Per Annum
# 96          Danna, Kyria M.  Employee   42000  Per Annum
# ...

# %%
speech = white_house[white_house.Position Title = 'SPEECHWRITER']
# Out:
#   File "<ipython-input-20-e9b97559bca2>", line 1
#     speech = white_house[white_house.Position Title = 'SPEECHWRITER']
#                                                   ^
# SyntaxError: invalid syntax

# %%
white = pd.read_csv("/Users/alexmahadevan/Downloads/2016-Report-White-House-Staff.csv")

# %%
white.head()
# Out:
#                              Name    Status  Salary  Pay Basis  \
# 0           Abizaid, Christine S.  Detailee  156552  Per Annum
# 1            Abraham, Yohannes A.  Employee  132000  Per Annum
# 2              Abramson, Jerry E.  Employee  157299  Per Annum
# 3  Adams-Falconer, Jr., Thomas M.  Employee   45613  Per Annum
# 4              Adler, Caroline E.  Employee  115664  Per Annum
#
#                                       Position_Title  White House Review
# 0                      ADVISOR TO THE CHIEF OF STAFF                 NaN
# 1  DEPUTY ASSISTANT TO THE PRESIDENT FOR INTERGOV...                 NaN
# 2  DEPUTY ASSISTANT TO THE PRESIDENT AND DIRECTOR...                 NaN
# 3   PRESS ASSISTANT FOR REGIONAL AND SPECIALTY MEDIA                 NaN
# 4  SPECIAL ASSISTANT TO THE PRESIDENT AND DIRECTO...                 NaN

# %%
speech = white[white.Position_Title = 'SPEECHWRITER']
# Out:
#   File "<ipython-input-23-d275236a4ce7>", line 1
#     speech = white[white.Position_Title = 'SPEECHWRITER']
#                                         ^
# SyntaxError: invalid syntax

# %%
    speech = white[white.Position_Title == 'SPEECHWRITER']

# %%
speech.head()
# Out:
#                   Name    Status  Salary  Pay Basis Position_Title  \
# 180  Heifetz, David A.  Employee   42613  Per Annum   SPEECHWRITER
#
#      White House Review
# 180                 NaN

# %%
analyst = white[white.Position_Title == 'ANALYST']

# %%
analyst.count()
# Out:
# Name                  14
# Status                14
# Salary                14
# Pay Basis             14
# Position_Title        14
# White House Review     0
# dtype: int64

# %%
white.Position_Title.count()
# Out:
# 472

# %%
automation = pd.read_cvs("/Users/alexmahadevan/Downloads/raw_state_automation_data.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-505b6dd0c1a2> in <module>()
# ----> 1 automation = pd.read_cvs("/Users/alexmahadevan/Downloads/raw_state_automation_data.csv")
#
# AttributeError: 'module' object has no attribute 'read_cvs'

# %%
import pandas as pd

# %%
automation = pd.read_cvs("/Users/alexmahadevan/Downloads/raw_state_automation_data.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-505b6dd0c1a2> in <module>()
# ----> 1 automation = pd.read_cvs("/Users/alexmahadevan/Downloads/raw_state_automation_data.csv")
#
# AttributeError: 'module' object has no attribute 'read_cvs'

# %%
automation = pd.read_csv("/Users/alexmahadevan/Downloads/raw_state_automation_data.csv")

# %%
automation.head()
# Out:
#        SOC                           Occupation  Probability  Alabama  Alaska  \
# 0  11-1011                     Chief Executives        0.015     1030     760
# 1  11-1021      General and Operations Managers        0.160    26930    6490
# 2  11-2011  Advertising and Promotions Managers        0.039       50      40
# 3  11-2021                   Marketing Managers        0.014      530     200
# 4  11-2022                       Sales Managers        0.013     2510     400
#
#    Arizona  Arkansas  California  Colorado  Connecticut   ...     \
# 0     5750      2710       31150       880         1410   ...
# 1    43300     20680      261780     41540        33280   ...
# 2      470       110        3760       480          300   ...
# 3     4790      1090       33390      3060         4970   ...
# 4    10650      2650       69180      4570         7040   ...
#
#    South Dakota  Tennessee   Texas   Utah  Vermont  Virginia  Washington  \
# ...

# %%
automation.sort_values('Probability' , ascending=False)
# Out:
#          SOC                                         Occupation  Probability  \
# 75   15-2091                           Mathematical Technicians       0.9900
# 59   13-2082                                      Tax Preparers       0.9900
# 403  43-4141                                New Accounts Clerks       0.9900
# 172  23-2093        Title Examiners; Abstractors; and Searchers       0.9900
# 408  43-5011                           Cargo and Freight Agents       0.9900
# 190  25-4031                                Library Technicians       0.9900
# 54   13-2053                             Insurance Underwriters       0.9900
# 425  43-9021                                  Data Entry Keyers       0.9900
# 540  49-9064                                    Watch Repairers       0.9900
# 380  41-9041                                      Telemarketers       0.9900
# 601  51-6051                                       Sewers; Hand       0.9900
# ...

# %%
automation.sort_values('Probability')
# Out:
#          SOC                                         Occupation  Probability  \
# 246  29-1125                            Recreational Therapists       0.0028
# 501  49-1011  First-Line Supervisors of Mechanics; Installer...       0.0030
# 29   11-9161                     Emergency Management Directors       0.0030
# 159  21-1023   Mental Health and Substance Abuse Social Workers       0.0031
# 250  29-1181                                       Audiologists       0.0033
# 158  21-1022                          Healthcare Social Workers       0.0035
# 243  29-1122                            Occupational Therapists       0.0035
# 269  29-2091                        Orthotists and Prosthetists       0.0035
# 233  29-1022                    Oral and Maxillofacial Surgeons       0.0036
# 291  33-1021  First-Line Supervisors of Fire Fighting and Pr...       0.0036
# 236  29-1031                       Dietitians and Nutritionists       0.0039
# ...
