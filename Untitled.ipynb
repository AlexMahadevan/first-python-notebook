# %%
import pandas as pd

# %%
jobs = pd.read_csv("/Users/alexmahadevan/Desktop/raw_state_automation_data.csv")

# %%
jobs_transposed = jobs.transpose()

# %%
jobs_transposed.head()
# Out:
#                           0                                1    \
# SOC                   11-1011                          11-1021
# Occupation   Chief Executives  General and Operations Managers
# Probability             0.015                             0.16
# Alabama                  1030                            26930
# Alaska                    760                             6490
#
#                                              2                   3    \
# SOC                                      11-2011             11-2021
# Occupation   Advertising and Promotions Managers  Marketing Managers
# Probability                                0.039               0.014
# Alabama                                       50                 530
# Alaska                                        40                 200
#
#                         4                                          5    \
# SOC                 11-2022                                    11-2031
# ...

# %%
jobs_transposed.to_csv("jonbs_transposed.csv")
