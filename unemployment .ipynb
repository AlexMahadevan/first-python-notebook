# %%
import pandas as pd

# %%
rate = pd.read_csv("/Users/alexmahadevan/Desktop/UNEMPLOYMENT RATE.csv")

# %%
jobs = pd.read_csv("/Users/alexmahadevan/Desktop/JOBS.csv")

# %%
rate.head(1)
# Out:
#   METRO_OR_STATE  2016_RATE  2017_RATE
# 0        Alabama        6.3        5.2

# %%
rate['RATE_CHANGE'] = (rate['2017_RATE'] - rate['2016_RATE']) / rate['2016_RATE']

# %%
jobs.head(1)
# Out:
#   STATE_OR_METRO  EMPLOYED_CHANGE  PERCENT_CHANGE
# 0        Alabama             34.8             1.8

# %%
jobs.sort_values("PERCENT_CHANGE" , ascending=False)
# Out:
#                      STATE_OR_METRO  EMPLOYED_CHANGE  PERCENT_CHANGE
# 176                       Manhattan              3.2             7.8
# 67                     Fort Collins             11.6             7.2
# 106                         Sebring              1.4             5.7
# 339                            Enid              1.5             5.4
# 175                        Lawrence              2.7             5.4
# 193                    Lake Charles              5.6             5.2
# 434                      St. George              3.1             5.1
# 61                        Yuba City              2.1             5.0
# 2                    Auburn-Opelika              3.0             4.8
# 132                      Boise City             14.7             4.8
# 25                             Yuma              2.4             4.6
# 135                        Lewiston              1.3             4.6
# 394                       Cleveland              2.1             4.6
# ...

# %%
jobs.sort_values("PERCENT_CHANGE")
# Out:
#                STATE_OR_METRO  EMPLOYED_CHANGE  PERCENT_CHANGE
# 487                    Casper             -1.5            -3.8
# 191           Houma-Thibodaux             -2.8            -3.2
# 247            Cape Girardeau             -1.3            -2.9
# 465                   Beckley             -1.0            -2.2
# 16                  Fairbanks             -0.8            -2.1
# 492                   Arecibo             -0.6            -1.8
# 490               Puerto Rico            -12.4            -1.4
# 421                San Angelo             -0.6            -1.2
# 335   Weirton-Steubenville(1)             -0.5            -1.2
# 497  San Juan-Carolina-Caguas             -6.8            -1.1
# 315               Rocky Mount             -0.6            -1.1
# 78                  Waterbury             -0.7            -1.0
# 196   Shreveport-Bossier City             -1.9            -1.0
# 424                 Texarkana             -0.6            -1.0
# ...

# %%
rate.head(1)
# Out:
#   METRO_OR_STATE  2016_RATE  2017_RATE  RATE_CHANGE
# 0        Alabama        6.3        5.2    -0.174603

# %%
rate.sort_values("RATE_CHANGE" , ascending=False)
# Out:
#                         METRO_OR_STATE  2016_RATE  2017_RATE  RATE_CHANGE
# 299                             Toledo        4.7        6.2     0.319149
# 165            Elizabethtown-Fort Knox        4.7        5.4     0.148936
# 168                          Owensboro        4.8        5.4     0.125000
# 166                  Lexington-Fayette        4.0        4.5     0.125000
# 293                   Cleveland-Elyria        5.7        6.4     0.122807
# 193                         Pittsfield        4.4        4.9     0.113636
# 164                      Bowling Green        4.5        5.0     0.111111
# 192                        New Bedford        5.4        6.0     0.111111
# 15                           Fairbanks        5.7        6.3     0.105263
# 188                      Massachusetts        4.0        4.4     0.100000
# 348                        Sioux Falls        2.3        2.5     0.086957
# 259  Buffalo-Cheektowaga-Niagara Falls        4.7        5.1     0.085106
# ...

# %%
rate.sort_values("RATE_CHANGE")
# Out:
#                         METRO_OR_STATE  2016_RATE  2017_RATE  RATE_CHANGE
# 63                      Grand Junction        6.1        3.6    -0.409836
# 140                     Elkhart-Goshen        3.7        2.3    -0.378378
# 142                         Fort Wayne        4.4        2.8    -0.363636
# 149                        Terre Haute        5.8        3.7    -0.362069
# 64                             Greeley        3.9        2.5    -0.358974
# 377                             Odessa        7.3        4.7    -0.356164
# 200            Detroit-Warren-Dearborn        5.7        3.7    -0.350877
# 146             Michigan City-La Porte        5.8        3.8    -0.344828
# 62                        Fort Collins        3.2        2.1    -0.343750
# 147                             Muncie        5.7        3.8    -0.333333
# 138                        Bloomington        5.4        3.6    -0.333333
# 145           Lafayette-West Lafayette        4.5        3.0    -0.333333
# ...
