# %%
import pandas

# %% [markdown]
# # First Python Notebook
#
# Hello world!

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
Jobs = pd.read_csv("/Users/alexmahadevan/Desktop/Employment Projections.csv")

# %%
Jobs.head()
# Out:
#                                                Title SOC_Code      2014  \
# 0  Accountants and auditors     \t \t\t\t\tShow/h...  13-2011  1,332.70
# 1  Actors     \t \t\t\t\tShow/hide Example Job Ti...  27-2011      69.4
# 2  Actuaries     \t \t\t\t\tShow/hide Example Job...  15-2011      24.6
# 3  Adhesive bonding machine operators and tenders...  51-9191      18.4
# 4  Administrative law judges, adjudicators, and h...  23-1021        15
#
#        2024  Change  Percent Openings_due_to_growth_replacement 2016_wage  \
# 0  1,475.10   142.4     10.7                                498    68,150
# 1      76.1     6.6      9.6                                 34       NaN
# 2        29     4.4     18.1                               11.7   100,610
# 3      17.1    -1.2     -6.8                                4.8    32,290
# 4      14.5    -0.5     -3.6                                2.2    92,110
#
#                            Education  Education_code       Experience  \
# ...

# %%
Jobs[Jobs.Typical entry-level education != 'Associate's degree']
# Out:
#   File "<ipython-input-14-59c30058d810>", line 1
#     Jobs[Jobs.Typical entry-level education != 'Associate's degree']
#                           ^
# SyntaxError: invalid syntax

# %%
Jobs[Jobs.Typical entry-level education != 'High school diploma or equivalent']

# %%
props.head()

# %%
Jobs.2016 median annual wage

# %%
Jobs."2016 median annual wage"

# %%
jobs = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Associate's Degrees/Jobs.csv")

# %%
jobs.display()

# %%
jobs.info()

# %%
jobs.Education()

# %%
jobs."Education"()

# %%
jobs.SOC_Code()

# %%
OLS(2016_wage ~ Education_code, data=jobs)

# %%
import statsmodels.formula.api as sm

# %%
props.prop_name.value_counts()

# %%
props.prop_name.value_counts().reset_index()

# %%
props.prop_name.value_counts()

# %%
jobs.Education.value_counts()

# %%
jobs.Education == 'Associate's degree'

# %%
jobs.Education == 'Doctoral or professional degree'

# %%
newjobs = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Associate's Degrees/Jobs.csv")

# %%
newjobs.Education.value_counts()
# Out:
# High school diploma or equivalent    335
# Bachelor's degree                    174
# No formal educational credential     109
# Doctoral or professional degree       63
# Associates degree                     48
# Postsecondary nondegree award         45
# Master's degree                       38
# Some college, no degree                6
# -                                      1
# Name: Education, dtype: int64

# %%
newjobs.Education == 'Associates degree'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 789    False
# 790    False
# 791    False
# 792    False
# 793    False
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# 800    False
# 801    False
# 802     True
# 803    False
# 804    False
# 805    False
# 806    False
# 807     True
# 808    False
# 809    False
# 810    False
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# 818    False
# Name: Education, Length: 819, dtype: bool

# %%
newjobs[newjobs.Education == 'Associates degree']
# Out:
#                                                  Title SOC_Code   2014   2024  \
# 9    Aerospace engineering and operations technicia...  17-3021   11.4   11.8
# 12   Agricultural and food science technicians     ...  19-4011     33   34.7
# 18   Air traffic controllers     \t \t\t\t\tShow/hi...  53-2021   24.5   22.4
# 36   Architectural and civil drafters     \t \t\t\t...  17-3011     94   91.2
# 57   Avionics technicians     \t \t\t\t\tShow/hide ...  49-2091   17.4   17.5
# 76   Broadcast technicians     \t \t\t\t\tShow/hide...  27-4012   30.1   28.2
# 88   Camera and photographic equipment repairers   ...  49-9061    3.7    3.8
# 91   Cardiovascular technologists and technicians  ...  29-2031     52   63.5
# 104  Chemical technicians     \t \t\t\t\tShow/hide ...  19-4031   66.5   67.7
# 112  Civil engineering technicians     \t \t\t\t\tS...  17-3022     74   77.6
# 138  Computer network support specialists     \t \t...  15-1152    181  194.6
# ...

# %%
associates = newjobs[newjobs.Education == 'Associates degree']

# %%
associates.2016_wage()

# %%
associates.2016_wage

# %%
associates.'2016_wage'

# %%
associates.2016_wage

# %%
associates.Percent

# %%
result = associates.sort([Change,Percent], decending=[1,0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-2f090d1673ef> in <module>()
# ----> 1 result = associates.sort([Change,Percent], decending=[1,0])
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
associates.sort_values(Percent)

# %%
associates.sort_values("Percent")

# %%
associates.sort_values("Percent", ascending=False)

# %%
associates.sort_values("Percent", ascending=False)

# %%
associates.sort_values("Percent", ascending=False).head()
# Out:
#                                                  Title SOC_Code   2014   2024  \
# 550  Occupational therapy assistants     \t \t\t\t\...  31-2011     33   47.1
# 598  Physical therapist assistants     \t \t\t\t\tS...  31-2021   78.7  110.7
# 807  Web developers     \t \t\t\t\tShow/hide Exampl...  15-1134  148.5    188
# 200  Diagnostic medical sonographers     \t \t\t\t\...  29-2032   60.7   76.7
# 91   Cardiovascular technologists and technicians  ...  29-2031     52   63.5
#
#      Change  Percent Openings_due_to_growth_replacement 2016_wage  \
# 550    14.1     42.7                               23.6    59,010
# 598    31.9     40.6                               54.7    56,610
# 807    39.5     26.6                               58.6    66,130
# 200    16.0     26.4                               27.5    69,650
# 91     11.5     22.2                               21.4    55,570
#
#              Education  Education_code Experience  Experience_code Training  \
# ...

# %%
props.prop_name.value_counts().reset_index()

# %%
props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.'

# %%
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()

# %%
merged.info()

# %%
merged.committee_position.value_counts()

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
oppose.amount.sum()

# %%
support.amount.sum()

# %%
support.amount.sum() / merged.amount.sum()

# %%
merged.sort_values("amount")

# %%
merged.sort_values("amount", ascending=False)

# %%
support.sort_values("amount", ascending=False).head()

# %%
oppose.sort_values("amount", ascending=False).head()

# %%
merged.groupby("committee_name_x").amount.sum()

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount"
                                                                , ascending=False)

# %%
merged.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)

# %%
merged.groupby(["contributor_state", "committee_position"]).amount.sum().reset_index().sort_values("contributor_state", ascending=True)

# %%
merged.Sum()

# %%
merged.values("contributor_state")

# %%
merged.amount("CA")

# %%
merged.amount('contributor_state')

# %%
merged.amount(contributor_state)

# %%
merged.amount("contributor_state"")

# %%
merged.amount.sum(contributor_state)

# %%
merged.amount.sum('contributor_state')

# %%
CA = merged[merged.contributor_state == 'CA']

# %%
CA/merged.amount.sum()

# %%
CA / merged.amount.sum()

# %%
CA.amount.sum() / merged.amount.sum()

# %%
1 - (CA.amount.sum() / merged.amount.sum())

# %%
CA.head()

# %%
associates.head()

# %%
associates.sort_values("Percent", ascending=False).head()

# %%
associates.sort_values("Percent", ascending=False)

# %%
highschool = newjobs[newjobs.Education == 'High school diploma or equivalent']

# %%
highschool.aum(Percent)

# %%
highschool.sum(Percent)

# %%
highschool.sort_values("Percent", ascending=False).head()

# %%
highschool.sort_values("Percent", ascending=False)

# %%
highschool.sort_values("2016_wage", ascending=False)

# %%
associates.sort_values("2016_wage", ascending=False)

# %% [markdown]
# # First Python Notebook
#
# Hello world!

# %% [markdown]
# import pandas as pd

# %%
top_supporters = support.groupby(
    ["contributor_firstname", "contributor_lastname"]
).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters.head()

# %%
top_supporters.head()

# %%
top_supporters.display()

# %%
top_supporters.head(10)

# %%
top_supporters

# %%
top_supporters = support.groupby(
    ["contributor_firstname", "contributor_lastname"]
).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters = support.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
top_supporters.head(10)

# %%
top_supporters = support.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)

# %%
top_supporters.head(10)

# %%
top_supporters.amount.plot.bar()

# %%
top_supporters.amount.plot.barh()

# %%
top_supporters.head(5).amount.plot.barh()

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_lastname)

# %%
top_supporters['contributor_fullname'] = top_supporters.contributor_firstname + " " + top_supporters.contributor_lastname

# %%
top_supporters.head()

# %%
chart = top_supporters.head(5).amount.plot.barh()
chart.set_yticklabels(top_supporters.contributor_fullname)

# %%
associates.to_csv("associates.csv")

# %%
associates.to_csv("associates.csv")

# %%
millennials = pd.read_xlsx("/Users/alexmahadevan/Desktop/Millenial200List.xlsx")

# %%
infrastructure = pd.read_xlsx("/Users/alexmahadevan/Desktop/Projects/Infrastructure/Infrastructure Jobs.csv")

# %%
infrastructure = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Infrastructure/Infrastructure Jobs.csv")

# %%
infrastructure.head(5)

# %%
infrastructure.sum_values(Degree)

# %%
infrastructure.Degree.value_counts()

# %%
infrastructure.sort_values("MedianWage")

# %%
infrastructure.sort_values("MedianWage", ascending=False)

# %%
infrastructure.sort_values("JobOutlook", ascending=False)

# %%
jobs.head()

# %%
newjobs.head()

# %%
newjobs.mean(Change)

# %%
newjobs.mean("Change")

# %%
newjobs.mean('Change')

# %%
newjobs.describe(Change)

# %%
newjobs.describe()

# %%
ChangeZ = (newjobs.Change - 11.952503)/40.375600

# %%
ChangeZ.head()

# %%
ChangeZ.value_sort()

# %%
ChangeZ.value_sort("Change")

# %%
ChangeZ.sort_values()

# %%
newjobs['Zchange'] = (newjobs.Change - 11.952503)/40.375600

# %%
newjobs.describe()

# %%
newjobs.sort_values("Zchange")

# %%
newjobs.sort_values("Change")

# %%
newjobs.describe()

# %%
newjobs['Zpercent'] = (newjobs.Percent - 4.468987)/12.012549

# %%
newsjobs.sort_values("Zpercent", ascending=False)

# %%
newjobs.sort_values("Zpercent", ascending=False)

# %%
high = newjobs[newjobs.Education == 'High school diploma or equivalent']

# %%
high.head()

# %%
high.describe()

# %%
high.sort_values("Zpercent", ascending=False)

# %%
newjobs.count_values("Education")

# %%
newjobs.sum_values("Education")

# %%
newjobs.sum("Education")

# %%
newjobs.head()

# %%
newjobs.head()

# %%
newsjobs.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9cc4222a1b2b> in <module>()
# ----> 1 newsjobs.describe()
#
# NameError: name 'newsjobs' is not defined

# %%
jobs = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Infrastructure/Infrastructure Jobs.csv")

# %%
jobs.describe()
# Out:
#           MedianWage  JobOutlook  Unnamed: 5  Unnamed: 6  Unnamed: 7
# count     106.000000  105.000000         0.0         0.0         0.0
# mean    52094.235849    0.057440         NaN         NaN         NaN
# std     21282.234004    0.104795         NaN         NaN         NaN
# min      3800.000000   -0.180000         NaN         NaN         NaN
# 25%     37987.500000    0.017000         NaN         NaN         NaN
# 50%     49270.000000    0.050000         NaN         NaN         NaN
# 75%     61690.000000    0.083000         NaN         NaN         NaN
# max    127820.000000    0.870000         NaN         NaN         NaN

# %%
jobs['Zwage'] = (jobs.MedianWage - 52094.235849)/21282.234004

# %%
jobs['Zoutlook'] = (jobs.JobOutlook - 0.057440)/0.104795

# %%
jobs.head()
# Out:
#                                        OCCUPATION  MedianWage  \
# 0                         Air Traffic Controllers      122410
# 1             Aircraft Cargo Handling Supervisors       51900
# 2      Aircraft Mechanics and Service Technicians       60270
# 3                 Airfield Operations Specialists       52380
# 4  Airline Pilots, Copilots, and Flight Engineers      127820
#
#                Degree  JobOutlook NumberofJobs  Unnamed: 5  Unnamed: 6  \
# 0  Associate's Degree       -0.09        24500         NaN         NaN
# 1         High School        0.00         7460         NaN         NaN
# 2    Technical School        0.01       137300         NaN         NaN
# 3  Associate's Degree        0.04         8760         NaN         NaN
# 4   Bachelor's Degree        0.05        81520         NaN         NaN
#
#    Unnamed: 7     Zwage  Zoutlook
# 0         NaN  3.303965 -1.406937
# 1         NaN -0.009127 -0.548118
# 2         NaN  0.384159 -0.452693
# ...

# %%
jobs['Zaverage'] = (jobs.Zwage + Zoutlook)/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-87565efc3772> in <module>()
# ----> 1 jobs['Zaverage'] = (jobs.Zwage + Zoutlook)/2
#
# NameError: name 'Zoutlook' is not defined

# %%
jobs['Zaverage'] = (jobs.Zwage + jobs.Zoutlook)/2

# %%
jobs.sort_values("Zaverage", ascending=False)
# Out:
#                                             OCCUPATION  MedianWage  \
# 21                                    Dredge Operators       42420
# 4       Airline Pilots, Copilots, and Flight Engineers      127820
# 15                                   Commercial Divers       49090
# 16                                   Commercial Pilots      105720
# 46               Marine Engineers and Naval Architects       93350
# 27                             Environmental Engineers       84890
# 0                              Air Traffic Controllers      122410
# 14                                     Civil Engineers       83540
# 96                               Construction managers       89300
# 40                                        Hydrologists       80480
# 50                                   Nuclear Engineers      102220
# 87   Transportation, Storage, and Distribution Mana...       89190
# 75                       Solar Photovoltaic Installers       39240
# ...

# %%
jobs['Zrank'] = (jobs.Zwage*0.2 + jobs.Zoutlook*0.8)

# %%
jobs.head()
# Out:
#                                        OCCUPATION  MedianWage  \
# 0                         Air Traffic Controllers      122410
# 1             Aircraft Cargo Handling Supervisors       51900
# 2      Aircraft Mechanics and Service Technicians       60270
# 3                 Airfield Operations Specialists       52380
# 4  Airline Pilots, Copilots, and Flight Engineers      127820
#
#                Degree  JobOutlook NumberofJobs  Unnamed: 5  Unnamed: 6  \
# 0  Associate's Degree       -0.09        24500         NaN         NaN
# 1         High School        0.00         7460         NaN         NaN
# 2    Technical School        0.01       137300         NaN         NaN
# 3  Associate's Degree        0.04         8760         NaN         NaN
# 4   Bachelor's Degree        0.05        81520         NaN         NaN
#
#    Unnamed: 7     Zwage  Zoutlook  Zaverage     Zrank
# 0         NaN  3.303965 -1.406937  0.948514 -0.464757
# 1         NaN -0.009127 -0.548118 -0.278622 -0.440320
# ...

# %%
jobs.sort_values("Zrank", ascending=False)
# Out:
#                                             OCCUPATION  MedianWage  \
# 21                                    Dredge Operators       42420
# 15                                   Commercial Divers       49090
# 75                       Solar Photovoltaic Installers       39240
# 27                             Environmental Engineers       84890
# 37                               Helpers--Electricians       29350
# 72       Septic Tank Servicers and Sewer Pipe Cleaners       36430
# 4       Airline Pilots, Copilots, and Flight Engineers      127820
# 46               Marine Engineers and Naval Architects       93350
# 25                                        Electricians       52720
# 10   Bus and Truck Mechanics and Diesel Engine Spec...       45170
# 14                                     Civil Engineers       83540
# 16                                   Commercial Pilots      105720
# 58             Plumbers, Pipefitters, and Steamfitters       51450
# ...

# %%
jobs.NumberofJobs.describe()
# Out:
# count        106
# unique       102
# top       137300
# freq           2
# Name: NumberofJobs, dtype: object

# %%
jobs.describe()
# Out:
#           MedianWage  JobOutlook  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# count     106.000000  105.000000         0.0         0.0         0.0
# mean    52094.235849    0.057440         NaN         NaN         NaN
# std     21282.234004    0.104795         NaN         NaN         NaN
# min      3800.000000   -0.180000         NaN         NaN         NaN
# 25%     37987.500000    0.017000         NaN         NaN         NaN
# 50%     49270.000000    0.050000         NaN         NaN         NaN
# 75%     61690.000000    0.083000         NaN         NaN         NaN
# max    127820.000000    0.870000         NaN         NaN         NaN
#
#               Zwage      Zoutlook    Zaverage       Zrank
# count  1.060000e+02  1.050000e+02  105.000000  105.000000
# mean   2.659827e-12  2.537653e-17   -0.004606   -0.001842
# std    1.000000e+00  1.000004e+00    0.633356    0.785283
# min   -2.269228e+00 -2.265757e+00   -1.478102   -1.950695
# ...

# %%
median(jobs.NumberofJobs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-da4dcd010e01> in <module>()
# ----> 1 median(jobs.NumberofJobs)
#
# NameError: name 'median' is not defined

# %%
mean(jobs.NumberofJobs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d431e546cc86> in <module>()
# ----> 1 mean(jobs.NumberofJobs)
#
# NameError: name 'mean' is not defined

# %%
jobs.mean(NumberofJobs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f6a066ed983f> in <module>()
# ----> 1 jobs.mean(NumberofJobs)
#
# NameError: name 'NumberofJobs' is not defined

# %%
jobs.sort_values("MedianWage")
# Out:
#                                             OCCUPATION  MedianWage  \
# 64              Rail Transportation Workers, All Other        3800
# 22      Electrical Power-Line Installers and Repairers        6810
# 52                         Packers and Packagers, Hand       22130
# 78                         Taxi Drivers and Chauffeurs       24300
# 42   Laborers and Freight, Stock, and Material Move...       25980
# 83   Transportation Attendants, Except Flight Atten...       26060
# 32                     Forest and Conservation Workers       26940
# 19                             Couriers and Messengers       28170
# 47                  Material Moving Workers, All Other       28370
# 104                                Helpers--carpenters       28810
# 38   Helpers--Pipelayers, Plumbers, Pipefitters, an...       29030
# 37                               Helpers--Electricians       29350
# 8                Bus Drivers, School or Special Client       30150
# ...

# %%
jobs.sort_values("JobOutlook", ascending=False)
# Out:
#                                             OCCUPATION  MedianWage  \
# 21                                    Dredge Operators       42420
# 15                                   Commercial Divers       49090
# 75                       Solar Photovoltaic Installers       39240
# 37                               Helpers--Electricians       29350
# 72       Septic Tank Servicers and Sewer Pipe Cleaners       36430
# 25                                        Electricians       52720
# 38   Helpers--Pipelayers, Plumbers, Pipefitters, an...       29030
# 78                         Taxi Drivers and Chauffeurs       24300
# 10   Bus and Truck Mechanics and Diesel Engine Spec...       45170
# 93                               Construction Laborers       33430
# 41              Industrial Truck and Tractor Operators       32469
# 27                             Environmental Engineers       84890
# 58             Plumbers, Pipefitters, and Steamfitters       51450
# ...

# %%
college = pd.read_csv("/Users/alexmahadevan/Downloads/databeats-college-completion/cc_institution_grads.csv")

# %%
college2 = d.read_csv("/Users/alexmahadevan/Downloads/databeats-college-completion/cc_institution_details.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e9235b1af3b5> in <module>()
# ----> 1 college2 = d.read_csv("/Users/alexmahadevan/Downloads/databeats-college-completion/cc_institution_details.csv")
#
# NameError: name 'd' is not defined

# %%
college2 = pd.read_csv("/Users/alexmahadevan/Downloads/databeats-college-completion/cc_institution_details.csv")

# %%
college2.head()
# Out:
#    unitid                            chronname        city    state   level  \
# 0  100654               Alabama A&M University      Normal  Alabama  4-year
# 1  100663  University of Alabama at Birmingham  Birmingham  Alabama  4-year
# 2  100690                   Amridge University  Montgomery  Alabama  4-year
# 3  100706  University of Alabama at Huntsville  Huntsville  Alabama  4-year
# 4  100724             Alabama State University  Montgomery  Alabama  4-year
#
#                   control                                              basic  \
# 0                  Public  Masters Colleges and Universities--larger prog...
# 1                  Public  Research Universities--very high research acti...
# 2  Private not-for-profit            Baccalaureate Colleges--Arts & Sciences
# 3                  Public  Research Universities--very high research acti...
# 4                  Public  Masters Colleges and Universities--larger prog...
#
# ...

# %%
college2.describe()
# Out:
#               unitid       long_x        lat_y  student_count  \
# count    3798.000000  3798.000000  3798.000000    3798.000000
# mean   226063.790416   -91.030391    38.134044    4476.135334
# std    105065.777685    15.684064     5.040303    7376.868923
# min    100654.000000  -159.395966    19.699720      23.000000
# 25%    155063.250000   -97.294767    34.299610     581.250000
# 50%    198075.000000   -86.828840    38.988143    1794.500000
# 75%    233745.000000   -79.966228    41.633128    5172.000000
# max    475291.000000   -67.243306    71.324702  170144.000000
#
#        awards_per_value  awards_per_state_value  awards_per_natl_value  \
# count       3798.000000             3798.000000            3798.000000
# mean          23.435176               22.845656              22.484044
# std           10.615140                6.322818               4.770449
# min            0.500000                3.200000              16.500000
# ...

# %%
college2.sort_values("student_count", ascending=False)
# Out:
#       unitid                                          chronname  \
# 3134  372213                       University of Phoenix Online
# 833   150987         Ivy Tech Community College-Central Indiana
# 552   135717                                 Miami Dade College
# 2683  227182                           Lone Star College system
# 2649  225423                          Houston Community College
# 2827  232946                Northern Virginia Community College
# 507   132903                      University of Central Florida
# 914   154022                                 Ashford University
# 2719  228547                             Tarrant County College
# 2816  232557                                 Liberty University
# 2125  204796                              Ohio State University
# 2724  228723            Texas A&M University at College Station
# 502   132709                                    Broward College
# 587   138187                         Valencia Community College
# ...

# %%
PUMS = pd.read_csv("/Users/alexmahadevan/Downloads/csv_hfl/ss15hfl.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d3cce00b31fc> in <module>()
# ----> 1 PUMS = pd.read_csv("/Users/alexmahadevan/Downloads/csv_hfl/ss15hfl.csv")
#
# NameError: name 'pd' is not defined

# %%
PUMS = pd.read_csv("/Users/alexmahadevan/Downloads/csv_hfl/ss15hfl.csv")

# %%
PUMS.head()
# Out:
#      insp RT       SERIALNO  DIVISION  PUMA00  PUMA10  REGION  ST   ADJHSG  \
# 0     NaN  H  2011000000012         5    1200      -9       3  12  1053874
# 1  1000.0  H  2011000000014         5    2402      -9       3  12  1053874
# 2  1500.0  H  2011000000069         5     701      -9       3  12  1053874
# 3  1500.0  H  2011000000071         5    3501      -9       3  12  1053874
# 4     NaN  H  2011000000074         5    2001      -9       3  12  1053874
#
#     ADJINC   ...    WGTP75  WGTP76  WGTP77  WGTP78  WGTP79  WGTP80  FFINCP  \
# 0  1073094   ...         5       3       9       8       6       8     1.0
# 1  1073094   ...       103      84     118     164     104     153     0.0
# 2  1073094   ...        13      14      15       4      12      18     0.0
# 3  1073094   ...         8       8      10       2      19       8     0.0
# 4  1073094   ...        11      13       5      14      14      19     0.0
#
#    FGRNTP  FHINCP  FSMOCP
# 0     1.0     1.0     NaN
# ...

# %%
PUMS.head(5)
# Out:
#      insp RT       SERIALNO  DIVISION  PUMA00  PUMA10  REGION  ST   ADJHSG  \
# 0     NaN  H  2011000000012         5    1200      -9       3  12  1053874
# 1  1000.0  H  2011000000014         5    2402      -9       3  12  1053874
# 2  1500.0  H  2011000000069         5     701      -9       3  12  1053874
# 3  1500.0  H  2011000000071         5    3501      -9       3  12  1053874
# 4     NaN  H  2011000000074         5    2001      -9       3  12  1053874
#
#     ADJINC   ...    WGTP75  WGTP76  WGTP77  WGTP78  WGTP79  WGTP80  FFINCP  \
# 0  1073094   ...         5       3       9       8       6       8     1.0
# 1  1073094   ...       103      84     118     164     104     153     0.0
# 2  1073094   ...        13      14      15       4      12      18     0.0
# 3  1073094   ...         8       8      10       2      19       8     0.0
# 4  1073094   ...        11      13       5      14      14      19     0.0
#
#    FGRNTP  FHINCP  FSMOCP
# 0     1.0     1.0     NaN
# ...

# %%
PUMS = pd.read_csv("/Users/alexmahadevan/Downloads/csv_hfl/ss15hfl.csv")

# %%
PUMS.SINK.describe()
# Out:
# count    454600.000000
# mean          1.004083
# std           0.063766
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           2.000000
# Name: SINK, dtype: float64

# %%
PUMS.VALP.describe()
# Out:
# count    2.857680e+05
# mean     2.334463e+05
# std      3.553955e+05
# min      1.000000e+02
# 25%      8.400000e+04
# 50%      1.500000e+05
# 75%      2.500000e+05
# max      3.292000e+06
# Name: VALP, dtype: float64

# %%
2.334463e+05
# Out:
# 233446.3

# %%
1.500000e+05
# Out:
# 150000.0

# %%
dw configure
# Out:
#   File "<ipython-input-1-9bb9f85b4171>", line 1
#     dw configure
#                ^
# SyntaxError: invalid syntax

# %%
dw configure
# Out:
#   File "<ipython-input-2-9bb9f85b4171>", line 1
#     dw configure
#                ^
# SyntaxError: invalid syntax

# %%
export DW_AUTH_TOKEN=<YOUR_TOKEN>
# Out:
#   File "<ipython-input-3-a3561437ce72>", line 1
#     export DW_AUTH_TOKEN=<YOUR_TOKEN>
#                        ^
# SyntaxError: invalid syntax

# %%
import datadotworld as dw

# %%
intro_dataset = dw.load_dataset('jonloyens/an-intro-to-dataworld-dataset')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-ffa96c15acac> in <module>()
# ----> 1 intro_dataset = dw.load_dataset('jonloyens/an-intro-to-dataworld-dataset')
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/datadotworld/__init__.pyc in load_dataset(dataset_key, force_update, profile)
#      87     ['changelog', 'datadotworldbballstats', 'datadotworldbballteam']
#      88     """
# ---> 89     return _get_instance(profile).load_dataset(dataset_key,
#      90                                                force_update=force_update)
#      91
#
# /Users/alexmahadevan/Code/first-python-notebook/lib/python2.7/site-packages/datadotworld/__init__.pyc in _get_instance(profile)
#      44                         if profile == 'default'
#      45                         else FileConfig(profile=profile))
# ...
